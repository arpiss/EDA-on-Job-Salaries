# %% [markdown]
# # **DATA ANALYSIS ON JOB DATASET**

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#For ignoring warning
import warnings
warnings.filterwarnings("ignore")

# %%
#Reading the dataset
df1=pd.read_csv('/content/ds_salaries.csv')
df1
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
#displays first 5 rows of the dataset
df1.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
#displays last 5 rows of the dataset
df1.tail()
# Out:
#      Unnamed: 0  work_year experience_level employment_type      job_title  \
# 602         602       2022               SE              FT  Data Engineer
# 603         603       2022               SE              FT  Data Engineer
# 604         604       2022               SE              FT   Data Analyst
# 605         605       2022               SE              FT   Data Analyst
# 606         606       2022               MI              FT   AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location company_size
# ...

# %%
#displays number of rows and columns
df1.shape
# Out:
# (607, 12)

# %%
#gives the statistical insight about the dataset
df1.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
df2=df1.drop(['salary','salary_currency','Unnamed: 0'],axis=1)     #used to delete the unnecessary columns
df2.shape    #displays the number of rows and columns after droping columns
# Out:
# (607, 9)

# %%
# provides a summary of the DataFrame
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary_in_usd       607 non-null    int64
#  5   employee_residence  607 non-null    object
#  6   remote_ratio        607 non-null    int64
#  7   company_location    607 non-null    object
#  8   company_size        607 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 42.8+ KB

# %%
#displays the count of null values in the dataset
df2.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
#Returns the total number of duplicate rows in the DataFrame df2.
df2.duplicated().sum()
# Out:
# np.int64(42)

# %%
#display all the columns that contains only integer values
df2.describe().astype(int)
# Out:
#        work_year  salary_in_usd  remote_ratio
# count        607            607           607
# mean        2021         112297            70
# std            0          70957            40
# min         2020           2859             0
# 25%         2021          62726            50
# 50%         2022         101570           100
# 75%         2022         150000           100
# max         2022         600000           100

# %%
#display the columns that includes objects/ non numeric values.
df2.describe(include='object')
# Out:
#        experience_level employment_type       job_title employee_residence  \
# count               607             607             607                607
# unique                4               4              50                 57
# top                  SE              FT  Data Scientist                 US
# freq                280             588             143                332
#
#        company_location company_size
# count               607          607
# unique               50            3
# top                  US            M
# freq                355          326

# %%
#Returns all unique values found in the 'experience_level' column of the DataFrame df2.
df2['experience_level'].unique()
# Out:
# array(['MI', 'SE', 'EN', 'EX'], dtype=object)

# %%
#Returns all unique values found in the 'salary_in_usd' column of the DataFrame df2.
df2['salary_in_usd'].nunique()
# Out:
# 369

# %%
#counts how many times each unique salary appears in the salary_in_usd column
df2['salary_in_usd'].value_counts()
# Out:
# salary_in_usd
# 100000    15
# 120000    12
# 150000    12
# 200000    10
# 135000     9
#           ..
# 144854     1
# 192564     1
# 110925     1
# 25000      1
# 150075     1
# Name: count, Length: 369, dtype: int64

# %%
#number of unique job titles in your dataset
df2['job_title'].nunique()
# Out:
# 50

# %%
#how many times each employment_type appears in the dataset.
df2['employment_type'].value_counts()
# Out:
# employment_type
# FT    588
# PT     10
# CT      5
# FL      4
# Name: count, dtype: int64

# %%
#how many times each experience appears in the dataset.
df2['experience_level'].value_counts()
# Out:
# experience_level
# SE    280
# MI    213
# EN     88
# EX     26
# Name: count, dtype: int64

# %%
# Renaming Experience level values
df2.experience_level.replace({'EN':'Entry-Level/Junior','MI':'Mid-level/Intermediate','SE':'Senior-level/Expert','EX':'Executive-level/Director'}, inplace=True)
df2['experience_level'].value_counts()
# Out:
# experience_level
# Senior-level/Expert         280
# Mid-level/Intermediate      213
# Entry-Level/Junior           88
# Executive-level/Director     26
# Name: count, dtype: int64

# %%
#describes the corelation bwt the columns that contains only integers
plt.figure(figsize=(6,6))
sns.heatmap(df2.select_dtypes(include=['number']).corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# This helps finding the correlation between numerical columns in the dataset and visualizing it as a heatmap.

# %%
#Returns the column names in df2 that have numeric data types.
df2.select_dtypes(include=['number']).columns
# Out:
# Index(['work_year', 'salary_in_usd', 'remote_ratio'], dtype='object')

# %%
# returns the column names in df2 that have object (typically string) data types.
df2.select_dtypes(include=['object']).columns
# Out:
# Index(['experience_level', 'employment_type', 'job_title',
#        'employee_residence', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# # **Categorical variables**

# %% [markdown]
# **Experience Level**

# %%
experience_count=df2['experience_level'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(
    autopct='%1.1f%%',
    colors=['gold', 'skyblue', 'lightcoral', 'lightgreen'],
    labels=experience_count.index,
    x=experience_count.values,
    wedgeprops={'edgecolor': 'black'}
)
plt.title("Experience Level Proportion")
plt.ylabel("")  # Hide y-label for better visibility
plt.show()

# %% [markdown]
# *   Creates a pie chart showing the proportion of each unique experience level in the df2['experience_level'] column

# %%
plt.figure(figsize=(10,6))
plt.title('Experience Levels of Data Science Jobs', fontsize=18)
ax = sns.countplot (x='experience_level', data=df2)
for i in ax.containers:
    ax.bar_label(i)
plt.xlabel('Experience Level', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.show()

# %% [markdown]
# *   Plots a bar chart showing the count of each experience level in data science jobs from df2

# %% [markdown]
# **Job Titles**

# %%
plt.figure(figsize=(15,15))
plt.title('Various Job Titles in Data Science', fontsize=20, fontweight='bold')
sns.countplot(y='job_title', data=df2, order=df2['job_title'].value_counts().index)
plt.xlabel('Count', fontsize=15, fontweight='bold')
plt.ylabel('Job Titles', fontsize=20, fontweight='bold')
plt.show()

# %% [markdown]
# *   Creates a horizontal bar chart displaying the count of various job titles in data science from df2

# %% [markdown]
# **Employment Type**

# %%
# Rename Employment Type values
df2.employment_type.replace({'PT':'Part-time','FT':'Full-time','CT':'Contract','FL':'Freelance'}, inplace=True)

# %%
#calculates and displays the relative frequency (proportion) of each unique employment type in the employment_type column of df2
emp_type_ratio = df2.employment_type.value_counts(normalize=True)
display(emp_type_ratio)
# Out:
# employment_type
# Full-time    0.968699
# Part-time    0.016474
# Contract     0.008237
# Freelance    0.006590
# Name: proportion, dtype: float64

# %%
employment_count=df2['employment_type'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(
    autopct='%1.1f%%',
    colors=['gold', 'skyblue', 'lightcoral', 'lightgreen'],
    labels=employment_count.index,
    x=employment_count.values,
    wedgeprops={'edgecolor': 'black'}
)
plt.title("Employment type Proportion")
plt.ylabel("")  # Hide y-label for better visibility
plt.show()

# %% [markdown]
# *   Creates a pie chart to visualize the proportion of each employment type in df2['employment_type']

# %%
plt.figure(figsize=(10,5))
plt.title('Employment Type of Data Science Jobs', fontsize=18)
ax = sns.countplot (x='employment_type', data=df2)
for i in ax.containers:
    ax.bar_label(i)
plt.show()

# %% [markdown]
# Plots a bar chart using Seaborn (sns.countplot) to show the number of data science job listings for each employment type in the df2 DataFrame.
#
# It also:
#
# *   Sets the figure size to 10x5 inches.
# *   Adds a title: "Employment Type of Data Science Jobs".
# *   Displays the count labels directly on top of each bar using ax.bar_label.
# *   Shows the plot with plt.show().

# %% [markdown]
# **Employee Residence & Company Location**

# %%
fig,axes=plt.subplots(1,2,figsize=(20,15))
sns.countplot(ax=axes[0],y='employee_residence', data=df2, order=df2['employee_residence'].value_counts().index)
sns.countplot(ax=axes[1],y='company_location', data=df2,  order=df2['company_location'].value_counts().index)

axes[0].set_title('Employee Residence', fontsize=25, fontweight='bold')
axes[0].set(xlabel=None)
axes[0].set(ylabel=None)
axes[1].set_title('Company Location', fontsize=25, fontweight='bold')
axes[1].set(xlabel=None)
axes[1].set(ylabel=None)

fig.supxlabel('Count', fontsize=20, fontweight='bold')
fig.supylabel('Location', fontsize=20, fontweight='bold')

plt.show()

# %% [markdown]
# For Employee Residence and Company location, the US is the highest in terms of frequency, followed by Great Britain. A total of over 300 Employees and Companies are resident in the US while other locations record values below 50 for both Employee residence and company location.

# %% [markdown]
# **Company Size**

# %%
# Rename Company Size
df2.company_size.replace({'S':'Small(<50)','M':'Medium(50-250)','L':'Large(>250)'}, inplace=True)
df2.company_size.value_counts()
# Out:
# company_size
# Medium(50-250)    326
# Large(>250)       198
# Small(<50)         83
# Name: count, dtype: int64

# %%
company1=df2['company_size'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(
    autopct='%1.1f%%',
    colors=['gold', 'skyblue', 'lightcoral'],
    labels=company1.index,
    x=company1.values,
    wedgeprops={'edgecolor': 'black'}
)
plt.title("company size Proportion")
plt.ylabel("")  # Hide y-label for better visibility
plt.show()

# %% [markdown]
# Creates a pie chart to visualize the proportion of different company sizes in df2['company_size'], with custom colors and labels showing the percentage of each category. It helps understand the distribution of company sizes in the dataset.

# %%
plt.figure(figsize=(8,6))
plt.title('Company Size', fontsize=18)
ax = sns.countplot (x='company_size', data=df2)
for i in ax.containers:
    ax.bar_label(i)
plt.show()

# %% [markdown]
# Creates a bar chart to show the count of data science jobs for each company size in df2['company_size'], with labeled bars, a title, and customized figure size. It helps visualize the distribution of company sizes in the dataset.

# %% [markdown]
# # **Numeric variables**

# %% [markdown]
# **Work Year**

# %%
work1=df2['work_year'].value_counts()
plt.figure(figsize=(5,5))
plt.pie(
    autopct='%1.1f%%',
    colors=['gold', 'skyblue', 'lightcoral'],
    labels=work1.index,
    x=work1.values,
    wedgeprops={'edgecolor': 'black'}
)
plt.title("work year Proportion")
plt.ylabel("")  # Hide y-label for better visibility
plt.show()

# %% [markdown]
# Creates a pie chart to visualize the proportion of different work years in df2['work_year'], showing the percentage of each year category with custom colors and labels. It helps understand the distribution of work years in the dataset.

# %% [markdown]
# **Salary in USD**

# %%
sns.histplot(df2['salary_in_usd'], bins=30, kde=True, color='blue')
# Out:
# <Axes: xlabel='salary_in_usd', ylabel='Count'>

# %% [markdown]
# Plots a histogram with 30 bins and a kernel density estimate (KDE) overlay for the df2['salary_in_usd'] column, displaying the distribution of salaries in blue.

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='salary_in_usd', data=df2)
plt.show()

# %% [markdown]
# Creates a box plot to visualize the distribution of df2['salary_in_usd'], displaying the median, quartiles, and any potential outliers in the salary data.

# %% [markdown]
# **Remote Ratio**

# %%
# Rename Employment Type values
df2.remote_ratio.replace({0:'No remote work',50:'Partially remote',100:'Fully remote'}, inplace=True)
df2.remote_ratio.value_counts()
# Out:
# remote_ratio
# Fully remote        381
# No remote work      127
# Partially remote     99
# Name: count, dtype: int64

# %%
plt.title ('Remote Ratio', fontsize=18)
ax = sns.countplot(x='remote_ratio', data=df2)
for i in ax.containers:
    ax.bar_label(i)

# %% [markdown]
# Creates a bar chart to visualize the count of each remote work ratio in df2['remote_ratio'], with labeled bars and a title "Remote Ratio" for clarity.

# %%
#code calculates and displays the relative frequency (proportion) of each unique value in the df2.remote_ratio column.
remote_work_ratio = df2.remote_ratio.value_counts(normalize=True)
display(remote_work_ratio)
# Out:
# remote_ratio
# Fully remote        0.627677
# No remote work      0.209226
# Partially remote    0.163097
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.lineplot(x='work_year', y='salary_in_usd', data=df2, estimator='mean', ci=None, marker='o', color='b')
plt.title("Average Salary Trend Over Years", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Average Salary (USD)", fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# Creates a line plot showing the average salary trend over the years (df2['work_year'] vs. df2['salary_in_usd']), with data points marked as circles. It visualizes how the average salary has changed over time, with gridlines for better readability.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='experience_level', y='salary_in_usd', data=df2, palette='Set2')
plt.title("Salary Distribution by Experience Level", fontsize=14)
plt.xlabel("Experience Level", fontsize=12)
plt.ylabel("Salary (USD)", fontsize=12)
plt.show()

# %% [markdown]
# Creates a box plot to visualize the distribution of salary_in_usd across different experience_level categories in df2, with a custom color palette. It includes labels and a title to help interpret the salary distribution by experience level.

# %%
plt.figure(figsize=(10,5))
df2['job_title'].value_counts().head(10).plot(kind='bar', color='royalblue')
plt.title("Top 10 Most Common Job Titles", fontsize=14)
plt.xlabel("Job Title", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Most Common Job Titles**
#
# Understands which job roles are most in demand.
#
# This bar chart shows the Top 10 Most Common Job Titles in the dataset, helping us understand which roles have the most job openings.

# %%
# relationships between all numerical columns
sns.pairplot(df2[['salary_in_usd', 'work_year', 'remote_ratio']])
plt.show()

# %% [markdown]
# Creates a pairplot to visualize the relationships between the numerical columns salary_in_usd, work_year, and remote_ratio in df2, showing scatter plots and histograms for each pair of variables.

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 row, 3 columns

axes[0].scatter(df2['work_year'], df2['salary_in_usd'], color='blue')
axes[0].set_title("Work Year vs Salary")

axes[1].scatter(df2['remote_ratio'], df2['salary_in_usd'], color='green')
axes[1].set_title("Remote Ratio vs Salary")

axes[2].scatter(df2['experience_level'], df2['salary_in_usd'], color='red')
axes[2].set_title("Experience Level vs Salary")

plt.tight_layout()  # Adjust layout to avoid overlap
plt.show()

# %% [markdown]
# # **Summary of Findings**
#
# The Dataset contains 607 records and 9 features.
#
# Unnamed column is not useful for our analysis (Dropped column).
#
# Data contains values from 2020 to 2022 Work Year.
#
# There are 50 unique job titles.

# %% [markdown]
# # **Conclusion**
#
# 1.   Experience Level: Experienced professionals tend to earn higher salaries, with the majority of jobs being full-time.
# 2.   Company Size: Larger companies dominate the hiring scene, likely offering higher salaries.
# 3.   Employment Type: Most jobs are full-time, with a smaller proportion of remote and partially remote positions.
# 4.   Work Year: Salaries vary across different work years, with some fluctuations in the dataset.
# 5.   Remote Work: Remote and partially remote jobs are growing but still not the majority.
# 6.   Experience & Salary: Experience level positively correlates with higher salary, while remote work and company size also impact earnings.

# %% [markdown]
# **Overall, the analysis highlights that experience and company size are key drivers of salary, while remote work options are becoming more common but remain a minority.**
